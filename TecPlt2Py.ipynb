# %% [markdown]
# ## Tecplot Mesh Plotter

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d.art3d import Poly3DCollection


# fig = plt.figure()
# ax = fig.add_subplot(111, projection='3d')

# # Sample 3D points
# points = [(1, 2, 3), (4, 5, 6), (7, 8, 9)]

# # Add annotations to each point
# for x, y, z in points:
#     ax.scatter(x, y, z)
#     ax.text(x, y, z, f'({x}, {y}, {z})', zdir='z') # zdir can be 'x', 'y' or a tuple

# ax.set_xlabel('X-axis')
# ax.set_ylabel('Y-axis')
# ax.set_zlabel('Z-axis')

## plt.show()

# %matplotlib widget

node_data = np.genfromtxt("inv_wing_tec_boundary.dat",usecols=(0,1,2),max_rows=432,skip_header=3)

node_xdata=node_data[:,0]
node_ydata=node_data[:,1]
node_zdata=node_data[:,2]

connectivity_data = np.genfromtxt("inv_wing_tec_boundary.dat",usecols=(0,1,2),skip_header=435,max_rows=724)
# Create a 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

for x, y, z in node_data:
    ax.scatter(x, y, z)
    ax.text(x, y, z, f'({x}, {y}, {z})', zdir='z') # zdir can be 'x', 'y' or a tuple

ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_zlabel('Z-axis')

plt.show()

## for j in connectivity_data:
#     print(node_data[int(j[0])], node_data[int(j[1])], node_data[int(j[2])])
#     triangle_data=[node_data[int(j[0]-1)], node_data[int(j[1]-1)], node_data[int(j[2]-1)]]

#     # Create a Poly3DCollection
#     triangle = Poly3DCollection([triangle_data],alpha=0.5)

#     # Add the triangle to the plot
#     ax.add_collection3d(triangle)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
